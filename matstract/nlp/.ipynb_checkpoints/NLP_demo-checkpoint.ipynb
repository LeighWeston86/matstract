# %% [markdown]
# ## Demo of NLP functionality
# Here we describe some of the available tools to help you with nlp tasks.

# %% [markdown]
# ### Annotations to POS / IOB Format

# %%
import os
os.chdir("/Users/vtshitoyan/dev/TRI/matstract")  # for some reason I have to do this to import matstract

# %% [markdown]
# `AnnotationBuilder` provides various functionality for dealing with annotations

# %%
from matstract.models.AnnotationBuilder import AnnotationBuilder
builder = AnnotationBuilder()
annotations = builder.get_annotations(user=None)  # you can specify the user_key to get annotations of specific user

# %% [markdown]
# `annotations` is a list of `Annotation` objects containing all relevant annotaiton information. You can use the `to_iob()` method to get part of speech tags and IOB annotation used for named entity recognition

# %%
iob, iob_str = annotations[0].to_iob()
print(iob[0])
# Out:
# [('The', 'DT', 'O'), ('effect', 'NN', 'O'), ('of', 'IN', 'O'), ('oxygen', 'NN', 'B-PRO'), ('nonstoichiometry', 'NN', 'I-PRO'), ('of', 'IN', 'O'), ('BaBi1', 'NN', 'B-MAT'), ('−', 'HYPH', 'I-MAT'), ('x', 'NN', 'I-MAT'), ('Pb', 'NN', 'I-MAT'), ('x', 'CC', 'I-MAT'), ('O3', 'NN', 'I-MAT'), ('−', 'HYPH', 'I-MAT'), ('δ', 'NN', 'I-MAT'), ('on', 'IN', 'O'), ('electrical', 'JJ', 'B-PRO'), ('conduction', 'NN', 'I-PRO'), ('behaviour', 'NN', 'O')]

# %% [markdown]
# You can also print the results as a plain string, which might be useful for portability

# %%
print(iob_str)
# Out:
# The DT O
# effect NN O
# of IN O
# oxygen NN B-PRO
# nonstoichiometry NN I-PRO
# of IN O
# BaBi1 NN B-MAT
# − HYPH I-MAT
# x NN I-MAT
# Pb NN I-MAT
# x CC I-MAT
# O3 NN I-MAT
# − HYPH I-MAT
# δ NN I-MAT
# on IN O
# electrical JJ B-PRO
# conduction NN I-PRO
# behaviour NN O
#
# The DT O
# dependence NN O
# of IN O
# oxygen NN B-PRO
# deficiency NN I-PRO
# , , O
# δ NN B-PRO
# , , O
# of IN O
# BaBi1 NN B-MAT
# − HYPH I-MAT
# xPbxO3 NN I-MAT
# − HYPH I-MAT
# δ NN I-MAT
# on IN O
# temperature NN B-CON
# , , O
# T NN B-CON
# , , O
# and CC O
# oxygen NN B-CON
# partial JJ I-CON
# pressure NN I-CON
# , , O
# Po2 NN B-CON
# , , O
# was VBD O
# investigated VBN O
# by IN O
# thermogravimetry NN O
# . . O
#
# A DT O
# linear JJ O
# relationship NN O
# with IN O
# proportionality NN B-PRO
# constant JJ I-PRO
# about IN O
# − HYPH B-PVL
# 1 CD I-PVL
# 2 CD I-PVL
# between IN O
# log NN O
# δ NN B-PRO
# and CC O
# log NN O
# pO2 NN B-CON
# observed VBN O
# for IN O
# the DT O
# specimens NNS O
# with IN O
# x NN B-PRO
# = JJ O
# 0.25 CD B-PVL
# , , O
# 0.5 CD B-PVL
# and CC O
# 0.75 CD B-PVL
# suggested VBD O
# that IN O
# effective JJ B-PRO
# concentration NN I-PRO
# of IN I-PRO
# electron NN I-PRO
# carrier NN I-PRO
# was VBD O
# independent JJ O
# of IN O
# δ NN B-PRO
# . . O
#
# The DT O
# decrease NN O
# of IN O
# electrical JJ B-PRO
# conductivity NN I-PRO
# with IN O
# δ NN B-PRO
# could MD O
# be VB O
# attributed VBN O
# to IN O
# the DT O
# decrease NN O
# of IN O
# electron NN B-PRO
# mobility NN I-PRO
# . . O
#
# From IN O
# our PRP$ O
# thermogravimetry NN O
# data NNS O
# , , O
# deduced VBN O
# were VBD O
# the DT O
# decrease NN O
# of IN O
# valence NN B-PRO
# state NN I-PRO
# of IN O
# Bi NNP B-MAT
# as IN O
# δ NN B-PRO
# increased VBD O
# and CC O
# the DT O
# localization NN B-PRO
# of IN I-PRO
# electrons NNS I-PRO
# generated VBN O
# from IN O
# oxygen NN B-MAT
# vacancy NN O
# around IN O
# Bi NN B-MAT
# site NN O
# , , O
# which WDT O
# agreed VBD O
# with IN O
# the DT O
# band NN B-PRO
# diagrams NNS I-PRO
# which WDT O
# was VBD O
# proposed VBN O
# based VBN O
# on IN O
# the DT O
# results NNS O
# of IN O
# photoelectron NN O
# spectroscopy NN O
# and CC O
# X-ray NN O
# absorption NN O
# . . O

# %% [markdown]
# ### Annotation Agreement Estimates

# %% [markdown]
# `AnnotationMetrics` provides a few useful tools for estimating inter-annotator agreement

# %%
from matstract.nlp.annotation_metrics import AnnotationMetrics
am = AnnotationMetrics()

# %% [markdown]
# You can extract the [Cohen Kappa Score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.cohen_kappa_score.html) using `cohen_kappa` method

# %%
# you can specify a list of labels and annotations
kappa, kappaStd, existing_labels = am.cohen_kappa(labels=None, annotators=None)  
print("Inter-annotator agreement is {:.2f} +/- {:.2f} %".format(kappa, kappaStd))
# Out:
# Inter-annotator agreement is 0.75 +/- 0.17 %

# %% [markdown]
# You can also get the similarity matrix across different labels

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matstract.nlp.utils import plot_matrix

similarity_matrix, labels = am.similarity_matrix()
plt.figure(figsize=(13,13))
plot_matrix(similarity_matrix, labels, normalize=True, title="Similarity Matrix")

# %% [markdown]
# A list of accuracies for different labels can be obtained

# %%
am.accuracies()
# Out:
# {'APL': 0.8292682926829268,
#  'CHM': 0.7253012048192771,
#  'CMT': 0.8571428571428571,
#  'CON': 0.6384976525821596,
#  'CUT': 0.8,
#  'CVL': 0.8195121951219512,
#  'DSC': 0.7115628970775095,
#  'MAT': 0.833922261484099,
#  'None': 0.9546455306032585,
#  'PMT': 0.5882352941176471,
#  'PRO': 0.7899461400359067,
#  'PUT': 0.8220858895705522,
#  'PVL': 0.794425087108014,
#  'QUA': 0.3055555555555556,
#  'REF': 0.43564356435643564,
#  'SMT': 0.8131868131868132,
#  'SPL': 0.5652173913043478}
